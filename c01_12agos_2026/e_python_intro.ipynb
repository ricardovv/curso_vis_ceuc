# %% [markdown]
# # INTRODUCCION A LA PROGRAMACIÓN CON PYTHON
#
# Prof. Ricardo Vega M.
#
# Python es un lenguaje de programación interpretado cuya filosofía hace hincapié en la legibilidad de su código. Es un lenguaje interpretado, dinámico y multiplataforma.
#
# Para saber un poco más de Python:
# https://ellibrodepython.com/que-es-python

# %% [markdown]
# Colab es un entorno tipo notebook (como Jupyter notebook) para ejecutar código.
# Tiene dos tipos de celda: para código Python y para código Markdown.
# Esta es una celda markdown (lenguaje simple para escribir HTML)
#
# # Este es un titulo H1.
# ## Este es un titulo H2.
# ### Este es un titulo H3.
# #### Este es un titulo H4.
# ##### Este es un titulo H5.
# ###### **Este es un titulo H6 en negrita.**
#
# Texto en **negrita**.

# %% [markdown]
# ## 1- Variables
#
# Pensar en las variables como una cajita con un nombre en donde se guardan valores que se pueden usar después.

# %%
## Suando usan # (hashtag) al inicio en una celda de código, indica que esa línea es un comentario

a = 1.0 # float
t = '5' # string

#print( type(t) ) # type() muestra que tipo de dato es
print( type(a) )
# Out:
# <class 'float'>

# %%
## Se pueden hacer operaciones aritméticas.
a = 5
b = 8
c = a + b

print( c )
# Out:
# 13

# %%
## Se pueden reescribir los valores de las variables
a = 7
a = 2
c = 1.5
print( a+c )
# Out:
# 3.5

# %%
## Se pueden guardar textos también! (tipo de dato string o str)
c = "Chao 'feo' "
n = 'Juan'
x = 'Bye'
print( c,n,x )
# Out:
# Chao 'feo'  Juan Bye

# %%
## Y también se pueden concatenar (juntar) textos.
a = 2 + 5
f = "la suma es: "

## Esta línea no funciona, por qué? (descomentar para probar)
#t = f + a

# str() cambia texto a número, cuando corresponde!
t = f + str(a)

t
# Out:
# 'la suma es: 7'

# %% [markdown]
# ## 2- Decisiones, if, else, elif
#
# Es la manera en que el comoutador toma desiciones, preguntando si un valor es tal o cual.

# %%
## Probar cambiando el valor de a (un = es asignar valores)
a = 5

## notar el doble igual (==) en este contexto indica comparacion entre valores
if a == 5:
    print("a vale 5")
else:
    print("a NO vale 5")
# Out:
# a vale 5

# %% [markdown]
# ## 3- Ciclos
#
# Permite repetir instrucciones según un límite.

# %%
## Para cada elemento i, entre 0 y n, se hace lo siguiente...

## Asi se escribe un ciclo en otros lenguajes, un poco mas largo...
# for(int i=0; i<3; i++ ){
#     hacer algo...
# }


for i in range( 0, 10 ):
    print( "i Vale: ", i )
# Out:
# i Vale:  0
# i Vale:  1
# i Vale:  2
# i Vale:  3
# i Vale:  4
# i Vale:  5
# i Vale:  6
# i Vale:  7
# i Vale:  8
# i Vale:  9

# %%
## Se pueden hacer operaciones a cada elemento
val = 3

for i in range( 10 ):
    print( "sumar val más", i, "es:", val + i )
# Out:
# sumar val más 0 es: 3
# sumar val más 1 es: 4
# sumar val más 2 es: 5
# sumar val más 3 es: 6
# sumar val más 4 es: 7
# sumar val más 5 es: 8
# sumar val más 6 es: 9
# sumar val más 7 es: 10
# sumar val más 8 es: 11
# sumar val más 9 es: 12

# %% [markdown]
# ## 4- Listas o Arrays
#
# Es una estructura de datos que sirve para tener una lista de muchos valores guardados con un mismo nombre.

# %%
## En este caso son textos que van entre comillas.

nombres = ['Ana','Beatriz','Claudia','Diana', 'Marcianeke']
edades  = [44, 23, 33, 12, 5]

print( nombres[2] , edades[2] ) ## cambiar valor entre los paréntesis cuadrados para acceder a otro nombre de la lista
# Out:
# Claudia 33

# %% [markdown]
# ## 5- Recorrer listas
#
# Se puede recorrer una lista con un ciclo.

# %%
## Toma cada elemento n de la lista nombres

## len(nombres) indica la cantidad de elementos de la lista nombres
for n in range( len(nombres) ):
    print( nombres[ n ] )
# Out:
# Ana
# Beatriz
# Claudia
# Diana
# Marcianeke

# %%
## Podemos tener listas de números también!

edades = ['cla',23,18,54,29,43,41,33]

l = len(edades)

for x in range( l ): ## len(nombres) indica la cantidad de elementos de la lista nombres
    print( edades[ x ] )
# Out:
# cla
# 23
# 18
# 54
# 29
# 43
# 41
# 33
